# %%
#정규표현식

print("Hello\nworld\\") # \n=줄바꿈 , \\ = \
# Out:
# Hello
# world\

# %%
print(r"\d") # r포맷은 \를 그대로 표현 가능
# Out:
# \d

# %%
import re

text = "apple banana cat"
result = re.findall(r"[abc]", text) # "apple banana cat"를 0부터 끝까지 "a", "b", "c" 중 일치하면 반환되는 리스트에 추가
print(result)
# Out:
# ['a', 'b', 'a', 'a', 'a', 'c', 'a']

# %%
text = "apple banana cat"

result= re.search(r"[at]", text)
print(result)
if result:
    print("a나t가 있다")
else:
    print("a나t가 없다")
# Out:
# <re.Match object; span=(0, 1), match='a'>
# a나t가 있다

# %%
#문자클래스[]: [] 안에 있는 문자 중 하나와 일치한다
#대괄호 [] 안의 "-"는 범위를 나타낸다
#대괄호 [] 안의 "^"은 제외하고를 나타낸다
#문장 앞의 ^은 시작을 나타낸다

# %%
import re

text = "A12B34"
print(re.findall(r"[0-9]", text))
# ['1', '2', '3', '4']
# 문자0부터 문자9까지 하나라도 일치하면 반환되는 리스트에 추가 
# 정규표현식 [0-9]는 [0123456789] 동일한 패턴
# Out:
# ['1', '2', '3', '4']

# %%
# 소대문자 포함, 특수문자 포함, 숫자문자 포함

import re

password= input("비밀번호:")

result=[]

if re.search(r"[가-핳]",password):
    result.append("한글을 사용할 수 없습니다")

if not re.search(r"[a-z]", password):
    result.append("소문자가 없습니다")

if not re.search(r"[A-Z]", password):
    result.append("대문자가 없습니다")

if not re.search(r"[0-9]", password):
    result.append("숫자가 없습니다")

if not re.search(r"[^0-9a-zA-Z가-핳]", password):
    result.append("특수문자가 없습니다")

if len(result)==0:
    result.append("사용 가능한 비밀번호입니다.")

result
# Out:
# ['한글을 사용할 수 없습니다']
